# %% [markdown]
# 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
#
# Ans: Values are ‘hello’, -87.8,6  Expressions are *,-,/ and +.
#
# 2. What is the difference between string and variable?
#
# Ans: String is a data type which is enclosed in “”. Ex: “My name is xyz”
# Variable is the one in which we store the data. Ex: a= "My name is xyz”.
# We can store a string inside a variable.
#
# 3. Describe three different data types.
#
# Ans: String : String is a data type which is enclosed in “”. Ex: “My name is xyz”
# String data type is indicated as “Str” in python. We can typecast a integer or float into str using str()
# Int : Int is a numerical data type which consists of all the positive and negative integers. We can typecast a float into int using int()
#  Ex: “45”, “105”, “-12”
# Float: Float is a numerical data type which consists of floating point numbers. We can typecast a int into float using float()
# Ex : “45.666”, “-56.455”
# Boolean: Boolean is the data type which consists of True and False. They are used for decision making. The value of True is 1 and False is 0.
# Ex: True, False
#
# 4. What is an expression made up of? What do all expressions do?
#
# Ans: Expressions are made up of mathematical operators. Some of the different expressions are “+”, “-“, “/” and “*”. Expressions are used for evluating the statements and for performing mathematical and decision making things.
# Addition expression is used to append a string or add one numerical value to other.
# Subtraction expression is used to subtract a numerical value from other.
# Division expression is used to divide a numerical value with other.
# Multiplication expression is used to Multiply the numerical values and also to get repeated strings.
#
# 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Ans: Expressions are the one’s made of operators like arithmetic and Boolean. They work with values and strings using operators. Statements are the lines of codes in python. Expression can also be a statement.
#
# 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans: 23
#
# 7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:‘spamspamspam’
# ‘spamspamspam'
#
# 8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans: A variable name can not be started with numerical values. That’s the reason eggs is a valid variable name while 100 is invalid
#
# 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans: int()
# float()
# str()
#
# 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans: Addition operators will not work with different data types as there are string and int data types in the above statement it causes an error. We can fix it by converting 99 into string by keeping it as “99” instead if 99.
